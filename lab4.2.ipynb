# %%
import os

base_folder = "lab_data"

if not os.path.exists(base_folder):
    os.mkdir(base_folder)

subfolders = ["input", "output", "logs"]

for folder in subfolders:
    path = os.path.join(base_folder, folder)
    if not os.path.exists(path):
        os.mkdir(path)


for item in os.listdir(base_folder):
    full_path = os.path.join(base_folder, item)

    if os.path.isfile(full_path):
        print(item, "-> File")
    else:
        print(item, "-> Directory")


old_name = os.path.join(base_folder, "logs")
new_name = os.path.join(base_folder, "history")

if os.path.exists(old_name):
    os.rename(old_name, new_name)

# %%
import os

input_path = os.path.join("lab_data", "input", "notes.txt")

with open(input_path, "w") as file:
    file.write("Line 1\n")
    file.write("Line 2\n")
    file.write("Line 3\n")
    file.write("Line 4\n")
    file.write("Line 5\n")


with open(input_path, "r") as file:
    lines = file.readlines()

print("Total lines:", len(lines))

output_path = os.path.join("lab_data", "output", "summary.txt")

with open(output_path, "w") as out:
    out.writelines(lines)

# %%
import pyfiglet
import os

text = pyfiglet.figlet_format("Nawaf")

output_file = os.path.join("lab_data", "output", "name_art.txt")

with open(output_file, "w") as file:
    file.write(text)

print(text)
