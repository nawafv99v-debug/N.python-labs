# %%
import pandas as pd   
import numpy as np    
import matplotlib.pyplot as plt   
 
data = pd.read_excel("C:\\Users\\nawaf\\OneDrive\\Desktop\\StudentMarks.xlsx")
 
print(data.head())    
print(data.tail())    
 
print(data.shape)    
print(data.dtypes)    
print(data.isnull().sum())   
 
print(np.mean(data["Marks"]))  
print(np.median(data["Marks"])) 
print(np.std(data["Marks"]))   
print(np.min(data["Marks"]))  
print(np.max(data["Marks"]))   
 
plt.bar(data["Name"], data["Marks"]) 
plt.show()     
 
plt.plot(data["Marks"])   
plt.show()    
 
plt.hist(data["Marks"])    
plt.show()
# Out:
#      Name  Age  Marks
# 0   nawaf   21     95
# 1  Khalid   22     78
# 2  Faisal   25     88
# 3   Noura   27     67
# 4    Reem   25     91
#           Name  Age  Marks
# 5  Abdulrahman   20     73
# 6         Sara   26     84
# 7        Turki   21     99
# 8         Huda   23     62
# 9        Majed   24     86
# (10, 3)
# Name     object
# Age       int64
# Marks     int64
# dtype: object
# Name     0
# Age      0
# Marks    0
# dtype: int64
# 82.3
# 85.0
# 11.47214016650773
# 62
# 99
